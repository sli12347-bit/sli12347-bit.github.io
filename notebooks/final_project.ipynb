aculis vel, suscipit quis, luctus non, massa. Fusce ac turpis quis ligula lacinia aliquet. Mauris ipsum.Lorem ipsum dolor sit amet, consectetur adipiscing elit. Integer nec odio. Praesent libero. Sed cursus ante dapibus diam. Sed nisi. Nulla quis sem at nibh elementum imperdiet. Duis sagittis ipsum. Praesent mauris. Fusce nec tellus sed augue semper porta. Mauris massa. Vestibulum lacinia arcu eget nulla. Class aptent taciti sociosqu ad litora torquent per conubia nostra, per inceptos himenaeos.

# %% [markdown]
# ### 2. Required Tools/Libraries

# %%
import sys
# !{sys.executable} -m pip install pandas numpy seaborn matplotlib
# Out:
# 411.66s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Collecting pandas
#   Downloading pandas-3.0.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 3.5 MB/s eta 0:00:00
# Collecting numpy
#   Downloading numpy-2.4.4-cp312-cp312-macosx_14_0_arm64.whl.metadata (6.6 kB)
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting matplotlib
#   Downloading matplotlib-3.10.9-cp312-cp312-macosx_11_0_arm64.whl.metadata (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 7.5 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/surabhisingh/Library/Python/3.12/lib/python/site-packages (from pandas) (2.9.0.post0)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.62.1-cp312-cp312-macosx_10_13_universal2.whl.metadata (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.5/117.5 kB 6.4 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.1 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/surabhisingh/Library/Python/3.12/lib/python/site-packages (from matplotlib) (26.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.2.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: six>=1.5 in /Users/surabhisingh/Library/Python/3.12/lib/python/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.2-cp312-cp312-macosx_11_0_arm64.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 12.3 MB/s eta 0:00:0000:0100:01
# ERROR: Could not install packages due to an OSError: [Errno 28] No space left on device: '/var/folders/t9/l9t3k75x6ql2n7syxl42t2kh0000gn/T/tmpx6wi74aq'
#
#
# [notice] A new release of pip is available: 24.0 -> 26.1.1
# [notice] To update, run: pip3.12 install --upgrade pip

# %%
# Import the necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[22], line 2
#       1 # Import the necessary libraries
# ----> 2 import pandas as pd
#       3 import numpy as np
#       4 import seaborn as sns
#
# ModuleNotFoundError: No module named 'pandas'

# %% [markdown]
# ### 3. Data Pre-Processing

# %%
# Load and view the dataset
df = pd.read_csv("../data/StudentsPerformance.csv")
df.head()

# %%
# Make column names into one string
df.columns = df.columns.str.lower().str.replace(" ", "_")

# %%
# Rename some columns with a better description
df = df.rename(columns = {
    "race/ethnicity": "race",
    "lunch": "lunch_plan",
    "test_preparation_course": "test_prep_status"
})
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Rename some columns with a better description
# ----> 2 df = df.rename(columns = {
#       3     "race/ethnicity": "race",
#       4     "lunch": "lunch_plan",
#       5     "test_preparation_course": "test_prep_status"
#
# NameError: name 'df' is not defined

# %%
# Checking for any missing values. None, so we are good!
df.isnull().sum()

# %%
# Check column data types
df.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Check column data types
# ----> 2 df.dtypes
#       3
#       4 # The scores are good already since they are integers. We need to make the first five columns into categorical data types, though.
#       5 categorical_columns = [
#
# NameError: name 'df' is not defined

# %%
# The scores are good already since they are integers. We need to make the first five columns into categorical data types, though.
categorical_columns = [
    "gender", "race", "parental_level_of_education", 
    "lunch_plan", "test_prep_status"
]

for col in categorical_columns:
    df[col] = df[col].astype("category")

df.dtypes
